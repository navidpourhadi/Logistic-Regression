# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/Logistic Regression/")
# !ls

# %%
from layers_utils import *
from activation_utils import *
from model.py import *
import time
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image

# %%
train_x, train_y, test_x, test_y, classes = dataset("train_catvnoncat.h5", "train_set_x", "train_set_y", "list_classes")
train_x = flatten(train_x)
test_x = flatten(test_x)

# %%
layers_dimensions = [12288, 20, 7, 5, 1]

# %%
parameters = L_layer_model(train_x, train_y, layers_dimensions, print_cost=True)

# %%
pred_train = predict(train_x, train_y, parameters)

# %%
pred_test = predict(test_x, test_y, parameters)
