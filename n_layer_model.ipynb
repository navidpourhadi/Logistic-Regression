# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/Logistic Regression/")
# !ls
# Out:
# activation_utils.py  model.py		  __pycache__  train_catvnoncat.h5
# layers_utils.py      n_layer_model.ipynb  results.png

# %%
from layers_utils import *
from activation_utils import *
from model import *
import time
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image

# %%
# dataset("/content/drive/MyDrive/Colab Notebooks/Logistic Regression/train_catvnoncat.h5", "train_set_x", "train_set_y", "list_classes")
train_x, test_x, train_y, test_y, classes = dataset("/content/drive/MyDrive/Colab Notebooks/Logistic Regression/train_catvnoncat.h5", "train_set_x", "train_set_y", "list_classes")
train_x = flatten_dataset(train_x)
test_x = flatten_dataset(test_x)
# Out:
# (209,)

# %%
layers_dimensions = [12288, 20, 7, 5, 1]

# %%
parameters = L_layer_model(train_x, train_y, layers_dimensions,lr=0.005,lambd=0.8,epoch=3000, print_cost=True)
# Out:
# W1.shape = (20, 12288)
# b1.shape = (20, 1)
# W2.shape = (7, 20)
# b2.shape = (7, 1)
# W3.shape = (5, 7)
# b3.shape = (5, 1)
# W4.shape = (1, 5)
# b4.shape = (1, 1)
# Cost after epoch 0: 0.889691
# Cost after epoch 50: 0.777563
# Cost after epoch 100: 0.735104
# Cost after epoch 150: 0.709499
# Cost after epoch 200: 0.691638
# Cost after epoch 250: 0.679012
# Cost after epoch 300: 0.669709
# Cost after epoch 350: 0.661268
# Cost after epoch 400: 0.653215
# Cost after epoch 450: 0.644517
# Cost after epoch 500: 0.634437
# Cost after epoch 550: 0.623513
# Cost after epoch 600: 0.611514
# Cost after epoch 650: 0.596742
# Cost after epoch 700: 0.579526
# Cost after epoch 750: 0.556619
# Cost after epoch 800: 0.526904
# Cost after epoch 850: 0.492280
# Cost after epoch 900: 0.451434
# Cost after epoch 950: 0.414515
# Cost after epoch 1000: 0.387178
# Cost after epoch 1050: 0.379042
# Cost after epoch 1100: 0.362906
# Cost after epoch 1150: 0.352899
# Cost after epoch 1200: 0.339055
# ...

# %%
pred_train = predict(train_x, train_y, parameters)
# Out:
# Accuracy: 1.0

# %%
pred_test = predict(test_x, test_y, parameters)
# Out:
# Accuracy: 0.6190476190476191
